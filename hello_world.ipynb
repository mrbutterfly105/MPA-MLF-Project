# %% [markdown]
# <a href="https://colab.research.google.com/github/mrbutterfly105/MPA-MLF-Project/blob/main/hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("PP turbo squad")
# Out:
# hello world
